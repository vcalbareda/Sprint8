# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
raw_df = pd.read_csv('lol2021.csv')
raw_df.sort_values('Team')
# Out:
#     Team    Player Opponent Position  Champion  Kills  Deaths  Assists  \
# 219  BYG      Kino      UOL  Support     Rakan      0       5        9
# 23   BYG     Husha       GS   Jungle  Xin Zhao      3       3        2
# 177  BYG     Doggo      DFM      Adc    Ezreal      1       1        2
# 25   BYG     Maoan       GS      Mid   Orianna      2       4        3
# 27   BYG     Doggo       GS      Adc    Ezreal      3       2        1
# ..   ...       ...      ...      ...       ...    ...     ...      ...
# 167  UOL  Argonavt       C9      Adc     Senna      2       0       16
# 169  UOL    Santas       C9  Support      Sion      2       1        9
# 34   UOL    Nomanz      DFM      Mid   Orianna      1       6        4
# 93   UOL  Ahahacik      BYG   Jungle   Lee Sin      0       4        3
# 0    UOL      Boss       GS      Top   Camille      4       5        3
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# ...

# %% [markdown]
# Tenemos un Data set con resultados de la liga de League of Legends 2021. Incluye distinos datos, tanto categóricos como numéricos.

# %%
raw_df.sort_values('Player')
# Out:
#     Team    Player Opponent Position      Champion  Kills  Deaths  Assists  \
# 49   INF  Ackerman      HLE  Support         Amumu      0       3        4
# 138  INF  Ackerman      PCE  Support         Rakan      0       2       12
# 68   INF  Ackerman      RED  Support          Nami      0       2        5
# 199  INF  Ackerman      LNG  Support         Braum      0       3        1
# 183  RED     Aegis      PCE   Jungle        Graves      4       5        4
# ..   ...       ...      ...      ...           ...    ...     ...      ...
# 17    C9      Zven      DFM      Adc  Miss Fortune      3       0        6
# 207   C9      Zven      DFM      Adc  Miss Fortune      2       4        3
# 166   C9      Zven      UOL      Adc  Miss Fortune      2       3        4
# 117   C9      Zven      BYG      Adc        Ezreal      9       1        5
# 86    C9      Zven       GS      Adc        Ezreal      6       1       12
#
# ...

# %%
ss = StandardScaler()

Xstd = ss.fit_transform(raw_df[['Kills', 'Wards Placed']].values)
print (Xstd.mean(), Xstd.std())
# Out:
# 5.652044489000796e-17 1.0

# %%
 x = raw_df[['Kills', 'Creep Score', 'Gold Earned']]
    mms = minMaxScaler()
    Xn = mms.fit_transform(x)
# Out:
#   File "<ipython-input-102-fc276509e1e8>", line 2
#     mms = minMaxScaler()
#     ^
# IndentationError: unexpected indent

# %%
print (Xn.min(axis=0))
print (Xn.max(axis=0))
